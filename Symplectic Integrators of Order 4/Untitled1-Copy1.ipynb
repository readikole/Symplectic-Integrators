# %%
import numpy as np 
import matplotlib
matplotlib.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt
import time
# %matplotlib notebook

# %%
#Fourth order symplectic integrator with 15 steps
start_time  = time.time()
#initialize vectors 
N = 50000
h = 1

# %%
##============intialize empty vectors==============##
x1 = np.zeros(N, dtype='float')
x2 = np.zeros(N, dtype='float')
dx1 = np.zeros(N, dtype='float')
dx2 = np.zeros(N, dtype='float')

# %%
##====================To do list========================##
#compute the phase of the 2d standard map

# %%
LCE = np.zeros(N, dtype='float')
vec = np.zeros(N, dtype='float')

# %%
#function for normalizing deviation vectors
def alpha(dx, dy):
    return np.linalg.norm([dx, dy])

# %%
from random import seed
from random import random

# %%
x1_vals = []
x2_vals = []

# %%
# seed random number generator
seed(1)
# generate random numbers between 0-1
for _ in range(1000):
    value = random()
    x1_vals.append(value)

# %%
# seed random number generator
seed(1)
# generate random numbers between 0-1
for _ in range(1000):
    value = random()
    x2_vals.append(value)

# %%
x1_vals = np.array(x1_vals)
x2_vals = np.array(x2_vals)

# %%
i = 0
for idx in range(len(x1_vals)):
#intial conditions 
    x1[0] = x1_vals[idx]
    x2[0] = x2_vals[idx]
    K =0.8
    for i in range(N-1):
        x1[i+1] = (x1[i] + x2[i] + (K/(2*np.pi))*np.sin(2*np.pi*x1[i]))%1
        x2[i+1] = (x2[i] + (K/(2*np.pi))*np.sin(2*np.pi*x1[i]))%1
    plt.scatter(x1, x2, s=0.0001)
    plt.title(r'\textbf{The phase portrait of the $2-D$ standard map}')
    plt.xlabel(r'$x_{1}$')
    plt.ylabel(r'$x_{2}$')
    #plt.xlim(0.3, 0.7)
    #plt.ylim(0.4, 0.65)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
end_time = time.time() - start_time 
end_time/60
# Out:
# 8.629807468255361
